# %%
from soco.music_services import MusicService 
import soco
devices = {device.player_name: device for device in soco.discover()}
# devices
# soco.discovery.discover
spotify_token = "BQD4PVj5fATjqxjLKIkVEG98UwCnECWvL_qe6pa2gWbdZbM5jw36VP7D_5nUT_keRe4mn0t7M7ytk_vZPD7tuIjLXlr98LHVAtB9e2UGGkc0PXP1dgjZsCRYaEnAqngViQ7cB4YXA8abzylsIvUVBXCuPJgA_BVwh_mh4y2SKYfaSojQ4jxF7_LDT2JXUfr1JjxX3BcnfFxArzsdxs83o9K2gaDxh0feBnNfK7eeE5AMlJRoJdvUdHBAEE59VRZrhWdwLycvEs0RuIzm7sekZq9e0ujlJYMPT8ODJOi6HL_o8lU9rnKGmogFB0vVQnOZF8tKkuM"
# spotify_token_pair = (spotify_token, result["privateKey"])

# %%
devices
garage = devices["Garage"]

# %%
from soco import SoCo
from soco.plugins.sharelink import ShareLinkPlugin

def add_spotify_link(share_link, device):

    print(f'Adding {share_link} on Sonos device #{device}')

    # device = SoCo(device_ip)

    # device.stop()
    # device.clear_queue()
    sharelink = ShareLinkPlugin(device)
    sharelink.add_share_link_to_queue(share_link)
    # device.play_from_queue(index=0)

# %%
uri = "x-spotify://spotify:track:2nGqLUUnLiTu93ltFV7BzC?"
add_spotify_link(uri, garage)
# Out:
# Playing x-spotify://spotify:track:2nGqLUUnLiTu93ltFV7BzC? on Sonos device #<SoCo object at ip 192.168.86.47>

# %%
from soco.plugins.spotify import SpotifyTrack
# garage.group.coordinator.add_to_queue("spotify:playlist:37i9dQZF1DXc6d8d2v4j0t")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 from soco.plugins.spotify import SpotifyTrack
#       2 # garage.group.coordinator.add_to_queue("spotify:playlist:37i9dQZF1DXc6d8d2v4j0t")
#
# File ~/dev/personal/sonos-mcp-server/.venv/lib/python3.13/site-packages/soco/plugins/spotify.py:32
#      30 # Only raise this import error if we are not building the docs
#      31 if not (os.environ.get("READTHEDOCS", None) == "True" or "sphinx" in sys.modules):
# ---> 32     raise RuntimeError(__doc__)
#
# RuntimeError: The Spotify plugin has been DEPRECATED
#
# The Spotify Plugin has been immediately deprecated (August 2016),
# because the API it was based on (The Spotify Metadata API) has been
# ended. Since this rendered the plug-in broken, there was no need to
# forewarn of the deprecation.
#
# ...

# %%
print(MusicService.get_all_music_services_names())
# Out:
# ['Radio Javan', 'Hit Network', 'storePlay', 'Triple M', 'Claro Música', 'CBC Radio & Music', 'Yogi Tunes', '90s90s Radio', 'AccuRadio', 'Amazon Music', 'Anghami', 'Apple Music', 'Audible', 'Bandcamp', 'Bookmate', 'Calm Radio', 'Classical Archives', 'Pandora CloudCover', 'Convoy Network', 'LITT Live', 'Deezer', 'Familystream', 'FIT Radio Workout Music', 'focus@will', 'Gaana', 'Qsic', 'Global Player', 'YouTube Music', 'IDAGIO', 'HEARTS of SPACE', 'Hype Machine', 'iBroadcast', 'iChill Music Service', 'iHeartRadio', 'Jukeboxy Music for Business', 'Mixcloud', 'Harmony', 'Murfie', 'Music Your Brand', 'NhacCuaTui', 'Libby by OverDrive', 'Pandora', 'Sveriges Radio', 'Pocket Casts', 'Qobuz', 'Audacy', 'Art Radio - RadioArt.com', 'Radio Paradise', 'RadioSparx Royalty-Free Music', 'TuneIn', 'Napster', 'Rockbot', 'Saavn', 'LiveOne', 'SomaFM Radio', 'SoundMachine', 'SoundCloud', 'Spotify', 'Storytel', 'The Lot Radio', 'TIDAL', 'toníque', 'radioPup', 'Tribe of Noise', 'Tunify for Business', 'Klass
# ...

# %%
spotify = MusicService('Spotify')
# Inspect the attributes and methods of the spotify object
print(dir(spotify))

# Look for methods or attributes related to tokens
# Optionally, you can filter the output for relevant keywords
token_related = [attr for attr in dir(spotify) if 'token' in attr.lower() or 'auth' in attr.lower()]
print("Token-related attributes and methods:", token_related)

# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_get_music_services_data', '_get_music_services_data_xml', '_get_search_prefix_map', '_music_services_data', '_search_prefix_map', 'auth_type', 'available_search_categories', 'begin_authentication', 'capabilities', 'complete_authentication', 'container_type', 'desc', 'get_all_music_services_names', 'get_data_for_name', 'get_extended_metadata', 'get_extended_metadata_text', 'get_last_update', 'get_media_metadata', 'get_media_uri', 'get_metadata', 'link_code', 'link_device_id', 'manifest_data', 'manifest_uri', 'presentation_map_uri', 'search', 'secure_uri', 'service_id', 'service_name', 'service_type', 'soap_client', 'sonos_uri_from_id', 'token_store', 'uri', 'version']
# Token-related attributes and methods: ['auth_type', 'begin_authentication', 'complete_authentication', 'token_store']

# write python to log any auth info for those. Write it NOW, no more comments or placeholders!!
print("Token-related attributes and methods:", token_related)
# NO DUMMY! PRINT THE VALUES OF THOSE ATTRIBUTES!!!
print("auth_type:", spotify.auth_type)
print("token_store:", spotify.token_store)
print("link_code:", spotify.link_code)
print("link_device_id:", spotify.link_device_id)
print("service_id:", spotify.service_id)
print("service_name:", spotify.service_name)

# OUTPUTS
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_get_music_services_data', '_get_music_services_data_xml', '_get_search_prefix_map', '_music_services_data', '_search_prefix_map', 'auth_type', 'available_search_categories', 'begin_authentication', 'capabilities', 'complete_authentication', 'container_type', 'desc', 'get_all_music_services_names', 'get_data_for_name', 'get_extended_metadata', 'get_extended_metadata_text', 'get_last_update', 'get_media_metadata', 'get_media_uri', 'get_metadata', 'link_code', 'link_device_id', 'manifest_data', 'manifest_uri', 'presentation_map_uri', 'search', 'secure_uri', 'service_id', 'service_name', 'service_type', 'soap_client', 'sonos_uri_from_id', 'token_store', 'uri', 'version']
# Token-related attributes and methods: ['auth_type', 'begin_authentication', 'complete_authentication', 'token_store']
# Token-related attributes and methods: ['auth_type', 'begin_authentication', 'complete_authentication', 'token_store']
# auth_type: AppLink
# token_store: <soco.music_services.token_store.JsonFileTokenStore object at 0x104aa47d0>
# link_code: None
# link_device_id: None
# service_id: 12
# service_name: Spotify
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_get_music_services_data', '_get_music_services_data_xml', '_get_search_prefix_map', '_music_services_data', '_search_prefix_map', 'auth_type', 'available_search_categories', 'begin_authentication', 'capabilities', 'complete_authentication', 'container_type', 'desc', 'get_all_music_services_names', 'get_data_for_name', 'get_extended_metadata', 'get_extended_metadata_text', 'get_last_update', 'get_media_metadata', 'get_media_uri', 'get_metadata', 'link_code', 'link_device_id', 'manifest_data', 'manifest_uri', 'presentation_map_uri', 'search', 'secure_uri', 'service_id', 'service_name', 
# ...

# %%
# NOW INSPECT THE TOKEN STORE 
print(dir(spotify.token_store))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_create_jsonable_key', '_token_store', 'filepath', 'from_config_file', 'has_token', 'load_token_pair', 'save_collection', 'save_token_pair', 'token_collection']

# %%
# check has token for spotify
has_spotify_token = spotify.token_store.has_token('Spotify', 'Sonos')
if has_spotify_token:
    print("Spotify token exists")
else:
    print("Spotify token does not exist")
    if spotify_token:
        print("Storing Spotify token")
        # Store the token
        # spotify.token_store.store_token('Spotify', 'Sonos', spotify_token)
# Out:
# Spotify token does not exist
# Storing Spotify token

# %%
auth1 = spotify.begin_authentication()
auth1
# Out:
# 'https://spotify-v5.ws.sonos.com/deviceLink/home?linkCode=9E85X44'

# %%
link_code = "9E85X44F"
auth2 = spotify.complete_authentication()
auth2

# %%
spotify.get_media_metadata(
item_id='spotify:track:6NmXV4o6bmp704aPGyTVVG')
# Out:
# {'id': 'spotify:track:6NmXV4o6bmp704aPGyTVVG',
#  'itemType': 'track',
#  'title': 'Bøn Fra Helvete (Live)',
#  'tags': {'explicit': '0'},
#  'mimeType': 'audio/x-spotify',
#  'trackMetadata': {'artistId': 'spotify:artist:1s1DnVoBDfp3jxjjew8cBR',
#   'artist': 'Kaizers Orchestra',
#   'albumId': 'spotify:album:6K8NUknbPh5TGaKeZdDwSg',
#   'album': 'Mann Mot Mann (Ep)',
#   'duration': '317',
#   'albumArtURI': 'https://i.scdn.co/image/ab67616d0000b2732841eb0b924040bb4d15ccc3',
#   'canPlay': 'true',
#   'canSkip': 'true',
#   'canAddToFavorites': 'true'}}

# %%
# spotify.available_search_categories
# spotify.search('artist', 'Björk',0,5)
# spotify.capabilities
spotify.auth_type
# spotify.get_all_music_services_names()
spotify.sonos_uri_from_id('spotify:track:6NmXV4o6bmp704aPGyTVVG')
# Out:
# 'soco://spotify%3Atrack%3A6NmXV4o6bmp704aPGyTVVG?sid=12&sn=0'

# %%
spotify.get_media_uri('spotify:track:6NmXV4o6bmp704aPGyTVVG')
# Out:
# 'x-spotify://spotify:track:2nGqLUUnLiTu93ltFV7BzC'

# %%
from soco.data_structures import DidlMusicTrack

# uri = 'x-spotify://spotify:track:2nGqLUUnLiTu93ltFV7BzC'
uri = spotify.get_media_uri('spotify:track:6NmXV4o6bmp704aPGyTVVG')
# add to sonos queue
device = devices['Garage']
# dir(device)

# inspect device to find coordinator


# device.get_queue()
# device.group.coordinator.add_uri_to_queue(uri)

# Correctly use the media URI method
spotify_uri = 'spotify:track:6NmXV4o6bmp704aPGyTVVG'
sonos_uri = spotify.get_media_uri(spotify_uri)

# Add to queue using the proper URI
device.group.coordinator.add_uri_to_queue(sonos_uri)
# Out:
# ---------------------------------------------------------------------------
# SoCoUPnPException                         Traceback (most recent call last)
# Cell In[47], line 20
#      17 sonos_uri = spotify.get_media_uri(spotify_uri)
#      19 # Add to queue using the proper URI
# ---> 20 device.group.coordinator.add_uri_to_queue(sonos_uri)
#
# File ~/dev/personal/sonos-mcp-server/.venv/lib/python3.13/site-packages/soco/core.py:147, in only_on_master.<locals>.inner_function(self, *args, **kwargs)
#     142     message = (
#     143         'The method or property "{}" can only be called/used '
#     144         "on the coordinator in a group".format(function.__name__)
#     145     )
#     146     raise SoCoSlaveException(message)
# --> 147 return function(self, *args, **kwargs)
#
# File ~/dev/personal/sonos-mcp-server/.venv/lib/python3.13/site-packages/soco/core.py:2260, in SoCo.add_uri_to_queue(self, uri, position, as_next, **kwargs)
# ...
